# %%
! pip install pandas langchain langchain-google-genai sentence-transformers tiktoken
# Out:
# ^C
# Requirement already satisfied: pandas in c:\users\afora\anaconda3\envs\ey\lib\site-packages (2.2.3)
# Collecting langchain
#   Using cached langchain-0.3.25-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-google-genai
#   Using cached langchain_google_genai-2.1.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting sentence-transformers
#   Using cached sentence_transformers-4.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tiktoken in c:\users\afora\anaconda3\envs\ey\lib\site-packages (0.9.0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from pandas) (2025.2)
# Collecting langchain-core<1.0.0,>=0.3.58 (from langchain)
#   Using cached langchain_core-0.3.62-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain)
#   Using cached langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langchain) (0.3.43)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langchain) (2.11.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (4.13.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: certifi in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: greenlet>=1 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from langchain-google-genai) (1.2.0)
# Collecting google-ai-generativelanguage<0.7.0,>=0.6.18 (from langchain-google-genai)
#   Using cached google_ai_generativelanguage-0.6.18-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.40.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (6.31.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.70.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.73.0rc1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.73.0rc1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.6.1)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Using cached transformers-4.52.3-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: tqdm in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from sentence-transformers) (2.7.0)
# Requirement already satisfied: scikit-learn in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from sentence-transformers) (0.32.2)
# Requirement already satisfied: Pillow in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: filelock in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\afora\anaconda3\envs\ey\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Using cached langchain-0.3.25-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.62-py3-none-any.whl (438 kB)
# Using cached langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Using cached langchain_google_genai-2.1.5-py3-none-any.whl (44 kB)
# Using cached google_ai_generativelanguage-0.6.18-py3-none-any.whl (1.4 MB)
# Using cached sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Using cached transformers-4.52.3-py3-none-any.whl (10.5 MB)
# Installing collected packages: transformers, sentence-transformers, langchain-core, google-ai-generativelanguage, langchain-text-splitters, langchain-google-genai, langchain
#
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ---------------------------------------- 0/7 [transformers]
#    ----- ---------------------------------- 1/7 [sentence-transformers]
#    ----- ---------------------------------- 1/7 [sentence-transformers]
#    ----- ---------------------------------- 1/7 [sentence-transformers]
#    ----- ---------------------------------- 1/7 [sentence-transformers]
#    ----- ---------------------------------- 1/7 [sentence-transformers]
#    ----- ---------------------------------- 1/7 [sentence-transformers]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------- ---------------------------- 2/7 [langchain-core]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ----------------- ---------------------- 3/7 [google-ai-generativelanguage]
#    ---------------------- ----------------- 4/7 [langchain-text-splitters]
#    ---------------------------- ----------- 5/7 [langchain-google-genai]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------------- 7/7 [langchain]
#
# Successfully installed google-ai-generativelanguage-0.6.18 langchain-0.3.25 langchain-core-0.3.62 langchain-google-genai-2.1.5 langchain-text-splitters-0.3.8 sentence-transformers-4.1.0 transformers-4.52.3

# %%
import os
import getpass

api_key = getpass.getpass(prompt="Insert your GOOGLE_API_KEY: ")

# %%
import getpass
from langchain_google_genai import ChatGoogleGenerativeAI
import tiktoken

# LLM configuration function
def config_llm_gemini(api_key: str, temperature: float = 0.7, model_name: str = "gemini-2.0-flash") -> ChatGoogleGenerativeAI:
    return ChatGoogleGenerativeAI(
        model=model_name,
        temperature=temperature,
        credentials={"api_key": api_key}
    )

llm = config_llm_gemini(api_key=api_key, temperature=0.7)

total_tokens = 0

# Usess encoding p50k_base with aproximation for Gemini
def count_tokens(text: str) -> int:
    enc = tiktoken.get_encoding('p50k_base')
    return len(enc.encode(text))

def validate_score(score: float) -> float:
    try:
        val = float(score)
    except:
        return 0.0
    if val < -5:
        return -5.0
    if val > 10:
        return 10.0
    return val

from langchain import PromptTemplate, LLMChain

def run_chain_and_count(llm, template: PromptTemplate, inputs: dict) -> str:
    global total_tokens
    prompt = template.format(**inputs)
    total_tokens += count_tokens(prompt)
    resp = LLMChain(llm=llm, prompt=template).run(inputs)
    total_tokens += count_tokens(resp)
    return resp.strip()

# Skills scoring
skills_template = PromptTemplate(
    input_variables=["skills", "job_desc"],
    template=(
        "Given the candidate's skills: {skills}\n"
        "And the job description: {job_desc}\n"
        "Rate how well the skills match the job on a scale of -5 to 10. Respond with just the number."
    )
)

def score_skills(llm, skills: str, job_desc: str) -> float:
    raw = run_chain_and_count(llm, skills_template, {"skills": skills, "job_desc": job_desc})
    return validate_score(raw)


# Education scoring
edu_template = PromptTemplate(
    input_variables=["education", "job_desc"],
    template=(
        "Given the candidate's education details: {education}\n"
        "- Consider university ranking and course relevance.\n"
        "- Award extra points for high GPA, but do not penalize low GPA.\n"
        "And the job description: {job_desc}\n"
        "Rate the education fit on a scale of -5 to 10. Respond with just the number."
    )
)

def score_education(llm, education: str, job_desc: str) -> float:
    raw = run_chain_and_count(llm, edu_template, {"education": education, "job_desc": job_desc})
    return validate_score(raw)

# Experience scoring
exp_template = PromptTemplate(
    input_variables=["experience", "job_desc"],
    template=(
        "Given the candidate's experience: {experience}\n"
        "And the job description: {job_desc}\n"
        "Rate how well the professional experience matches the job requirements on a scale of -5 to 10. Respond with just the number."
    )
)

def score_experience(llm, experience: str, job_desc: str) -> float:
    raw = run_chain_and_count(llm, exp_template, {"experience": experience, "job_desc": job_desc})
    return validate_score(raw)
    
# Summary scoring
summary_template = PromptTemplate(
    input_variables=["summary", "job_desc"],
    template=(
        "Given the candidate's summary text: {summary}\n"
        "And the job description: {job_desc}\n"
        "Rate how well the summary aligns with the role on a scale of -5 to 10. Respond with just the number."
    )
)
    
def score_summary(llm, summary: str, job_desc: str) -> float:
    raw = run_chain_and_count(llm, summary_template, {"summary": summary, "job_desc": job_desc})
    return validate_score(raw)

# Weighted sum of the scores
weights = {"skills": 1.0, "education": 1.0, "experience": 1.0, "summary": 1.0}
Total_w = sum(weights.values())

def final_score(row, desc: str) -> float:
    sk = score_skills(llm, row['skills'], desc)
    ed = score_education(llm, row['education'], desc)
    ex = score_experience(llm, row['experience'], desc)
    sm = score_summary(llm, row['summary'], desc)
    return (weights['skills']*sk + weights['education']*ed + weights['experience']*ex + weights['summary']*sm) / total_w

# %%
import pandas as pd

# 6. Função de teste com exemplos hipotéticos
def run_example():
    # Cria CSVs de exemplo
    example_profiles = [
        {"summary": "Data analyst with financial modeling and visualization expertise.",
         "education": "University of Oxford (Ranked 5), MSc in Finance, GPA: 3.9",
         "experience": "4 years at FinAnalytics LLC focusing on dashboard development.",
         "skills": "Python; SQL; Tableau; Power BI"},
        {"summary": "Backend engineer with microservices architecture background.",
         "education": "Stanford University (Ranked 2), BSc in Computer Science, GPA: 4.0",
         "experience": "3 years at CloudNative Inc building scalable APIs.",
         "skills": "Java; Spring Boot; Docker; Kubernetes"}
    ]
    pd.DataFrame(example_profiles).to_csv('profiles_preprocessed.csv', index=False)
    example_job = [{"description_text": "Seeking Senior Data Analyst with strong Python, SQL and BI tool experience to join finance team."}]
    pd.DataFrame(example_job).to_csv('job_1_description.csv', index=False)
    # Gera descrições dummy para as restantes vagas
    for i in range(2, 6):
        pd.DataFrame(example_job).to_csv(f'job_{i}_description.csv', index=False)
    # Executa pipeline
    for job, df in job_dfs.items():
        desc = df.loc[0, 'description_text']
        profiles_df[f'final_score_{job}'] = profiles_df.apply(lambda r: final_score(r, desc), axis=1)
    profiles_df.to_csv('profiles_scored.csv', index=False)
    print("Resultados de exemplo:")
    print(profiles_df)
    print(f"Total tokens usados: {total_tokens}")

# 7. Executar exemplo para verificar funcionalidade
run_example()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 30
#      27     print(f"Total tokens usados: {total_tokens}")
#      29 # 7. Executar exemplo para verificar funcionalidade
# ---> 30 run_example()
#
# Cell In[13], line 14, in run_example()
#       2 def run_example():
#       3     # Cria CSVs de exemplo
#       4     example_profiles = [
#       5         {"summary": "Data analyst with financial modeling and visualization expertise.",
#       6          "education": "University of Oxford (Ranked 5), MSc in Finance, GPA: 3.9",
#    (...)
#      12          "skills": "Java; Spring Boot; Docker; Kubernetes"}
#      13     ]
# ---> 14     pd.DataFrame(example_profiles).to_csv('profiles_preprocessed.csv', index=False)
#      15     example_job = [{"description_text": "Seeking Senior Data Analyst with strong Python, SQL and BI tool experience to join finance team."}]
#      16     pd.DataFrame(example_job).to_csv('job_1_description.csv', index=False)
#
# NameError: name 'pd' is not defined
